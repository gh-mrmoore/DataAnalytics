# %%
# Include this line to make plots interactive
# %matplotlib notebook

# Make plots display in-line
# %matplotlib inline

# %%
import matplotlib.pyplot as plt
import numpy as np
import os

# %%
cities = ["New Orleans", "Milwaukee", "Omaha", "Pittsburgh", "Toledo"]
bars_in_cities = [8.6, 8.5, 8.3, 7.9, 7.2]
x_axis = np.arange(len(bars_in_cities))

# %%
# %%time
# Create a bar chart based upon the above data
# plt.bar(x_axis, bars_in_cities)
plt.bar(cities, bars_in_cities, color="green")  # I think this looks better and is more descriptive

# Create the ticks for our bar chart's x axis
plt.xticks()

# Set the limits of the x axis
# plt.xlim(-.75, 4.75)

# Set the limits of the y axis
plt.ylim(0, 9)

# Give the chart a title, x label, and y label
plt.xlabel("Cities")
plt.ylabel("# of Bars")
plt.title("Bars by City")
# Save an image of the chart and print it to the screen
file_name = os.path.join("Images", "bar_bar_chart")
plt.savefig(file_name, orientation="landscape")
# Out:
# Wall time: 144 ms
